# %% [markdown]
# # Sklearn库
#
# ## 思维导图
# ![dt1](./pcs/dt1.png "dt1")
#
# scikit-learn 库是当今最流行的机器学习算法库之一
#
# 可用来解决分类与回归问题
#
# 本章以鸢尾花数据集为例，简单了解八大传统机器学习分类算法的sk-learn实现
#
# 欲深入了解传统机器学习算法的原理和公式推导，请继续学习《统计学习方法》或《西瓜书》
#
# ## 0. 鸢尾花数据集

# %% [markdown]
# [1]. 下载数据集

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# [2]. 数据集的查看

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.pairplot(data = iris, hue = "species")

# %% [markdown]
# [3]. 标签清洗

# %%
iris_simple = iris.drop(["sepal_length", "sepal_width"], axis = 1)
iris_simple.head()
# Out:
#    petal_length  petal_width species
# 0           1.4          0.2  setosa
# 1           1.4          0.2  setosa
# 2           1.3          0.2  setosa
# 3           1.5          0.2  setosa
# 4           1.4          0.2  setosa

# %% [markdown]
# [4]. 标签编码

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
iris_simple["species"] = encoder.fit_transform(iris_simple["species"])

# %%
iris_simple.head()
# Out:
#    petal_length  petal_width  species
# 0           1.4          0.2        0
# 1           1.4          0.2        0
# 2           1.3          0.2        0
# 3           1.5          0.2        0
# 4           1.4          0.2        0

# %% [markdown]
# [5]. 数据集的标准化（本数据集特征比较接近，实际处理过程中未标准化）

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
trans = StandardScaler()
_iris_simple = trans.fit_transform(iris_simple[["petal_length", "petal_width"]])
_iris_simple = pd.DataFrame(_iris_simple, columns = ["petal_length", "petal_width"])
_iris_simple.describe()
# Out:
#        petal_length   petal_width
# count  1.500000e+02  1.500000e+02
# mean  -4.263256e-16 -4.736952e-16
# std    1.003350e+00  1.003350e+00
# min   -1.567576e+00 -1.447076e+00
# 25%   -1.226552e+00 -1.183812e+00
# 50%    3.364776e-01  1.325097e-01
# 75%    7.627583e-01  7.906707e-01
# max    1.785832e+00  1.712096e+00

# %% [markdown]
# [6]. 构建训练集和测试集（暂不考虑验证集）

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(iris_simple, test_size = 0.2)
test_set.head()
# Out:
#      petal_length  petal_width  species
# 79            3.5          1.0        1
# 137           5.5          1.8        2
# 136           5.6          2.4        2
# 116           5.5          1.8        2
# 141           5.1          2.3        2

# %%
iris_x_train = train_set[["petal_length", "petal_width"]]
iris_x_train.head()
# Out:
#      petal_length  petal_width
# 48            1.5          0.2
# 127           4.9          1.8
# 88            4.1          1.3
# 75            4.4          1.4
# 76            4.8          1.4

# %%
iris_y_train = train_set["species"].copy()
iris_y_train.head()
# Out:
# 48     0
# 127    2
# 88     1
# 75     1
# 76     1
# Name: species, dtype: int32

# %%
iris_x_test = test_set[["petal_length", "petal_width"]]
iris_x_test.head()
# Out:
#      petal_length  petal_width
# 79            3.5          1.0
# 137           5.5          1.8
# 136           5.6          2.4
# 116           5.5          1.8
# 141           5.1          2.3

# %%
iris_y_test = test_set["species"].copy()
iris_y_test.head()
# Out:
# 79     1
# 137    2
# 136    2
# 116    2
# 141    2
# Name: species, dtype: int32

# %% [markdown]
# # 1. k近邻算法
# [1]. 基本思想
#
# 与待测点最近的训练数据集中的k个邻居
#
# 把k个近邻中最常见的类别预测为带预测点的类型
#
# ![k](./pcs/k.png "k")
#
# [2]. sklearn实现

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# - 构建分类器对象

# %%
clf = KNeighborsClassifier()
clf
# Out:
# KNeighborsClassifier()

# %% [markdown]
# - 训练

# %%
clf.fit(iris_x_train, iris_y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# - 预测

# %%
res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]

# %% [markdown]
# - 翻转

# %%
encoder.inverse_transform(res)
# Out:
# array(['versicolor', 'virginica', 'virginica', 'virginica', 'virginica',
#        'setosa', 'setosa', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'virginica', 'virginica', 'virginica', 'setosa', 'versicolor',
#        'virginica', 'setosa', 'versicolor', 'virginica', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'setosa'], dtype=object)

# %% [markdown]
# - 评估

# %%
accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))
# Out:
# 预测正确率：93%

# %% [markdown]
# - 存储数据

# %%
out = iris_x_test.copy()
out["y"] = iris_y_test
out["pre"] = res
out
# Out:
#      petal_length  petal_width  y  pre
# 79            3.5          1.0  1    1
# 137           5.5          1.8  2    2
# 136           5.6          2.4  2    2
# 116           5.5          1.8  2    2
# 141           5.1          2.3  2    2
# 24            1.9          0.2  0    0
# 43            1.6          0.6  0    0
# 132           5.6          2.2  2    2
# 109           6.1          2.5  2    2
# 10            1.5          0.2  0    0
# 5             1.7          0.4  0    0
# 70            4.8          1.8  1    2
# 69            3.9          1.1  1    1
# 82            3.9          1.2  1    1
# 45            1.4          0.3  0    0
# 125           6.0          1.8  2    2
# 112           5.5          2.1  2    2
# 83            5.1          1.6  1    2
# 108           5.8          1.8  2    2
# 0             1.4          0.2  0    0
# 50            4.7          1.4  1    1
# 115           5.3          2.3  2    2
# 14            1.2          0.2  0    0
# 68            4.5          1.5  1    1
# 131           6.4          2.0  2    2
# 36            1.3          0.2  0    0
# 64            3.6          1.3  1    1
# 65            4.4          1.4  1    1
# 102           5.9          2.1  2    2
# 1             1.4          0.2  0    0

# %%
out.to_csv("./pcs/iris_predict.csv")

# %% [markdown]
# [3]. 可视化

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

def draw(clf):
    
    # 网格化
    M, N = 500, 500
    x1_min, x2_min = iris_simple[["petal_length", "petal_width"]].min(axis = 0)
    x1_max, x2_max = iris_simple[["petal_length", "petal_width"]].max(axis = 0)
    t1 = np.linspace(x1_min, x1_max, M)
    t2 = np.linspace(x2_min, x2_max, N)
    x1, x2 = np.meshgrid(t1, t2)
    
    # 预测
    x_show = np.stack((x1.flat, x2.flat), axis = 1)
    y_predict = clf.predict(x_show)
    
    # 配色
    cm_light = mpl.colors.ListedColormap(["#A0FFA0", "#FFA0A0", "#A0A0FF"])
    cm_dark = mpl.colors.ListedColormap(["g", "r", "b"])
    
    # 绘制预测区域图
    plt.figure(figsize = (10, 6))
    plt.pcolormesh(t1, t2, y_predict.reshape(x1.shape), cmap = cm_light)
    
    # 绘制原始数据点
    plt.scatter(iris_simple["petal_length"], iris_simple["petal_width"], label = None,
               c = iris_simple["species"], cmap = cm_dark, marker = 'o', edgecolors = 'k')
    plt.xlabel("petal_length")
    plt.ylabel("petal_width")
    
    # 绘制图例
    color = ["g", "r", "b"]
    species = ["setosa", "virginica", "versicolor"]
    for i in range(3):
        plt.scatter([], [], c = color[i], s = 40, label = species[i])  # 利用空点绘制图例
    plt.legend(loc = "best")
    plt.title('iris_classfier')
    plt.show()

# %%
draw(clf)
# Out:
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 2. 朴素贝叶斯算法
#
# [1]. 基本思想
#
# 当X = (x1, x2)发生的时候，哪一个yk发生的概率最大
#
# [2]. sklearn实现

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# - 构建分类器对象

# %%
clf = GaussianNB()
clf
# Out:
# GaussianNB()

# %% [markdown]
# - 训练

# %%
clf.fit(iris_x_train, iris_y_train)
# Out:
# GaussianNB()

# %% [markdown]
# - 预测

# %%
res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]

# %% [markdown]
# - 评估

# %%
accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))
# Out:
# 预测正确率：93%

# %% [markdown]
# - 可视化

# %%
draw(clf)
# Out:
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 决策树算法
#
# [1]. 基本思想
#
# CART算法：每次通过一个特征，将数据尽可能的分为纯净的两类，递归的分下去
#
# [2]. sklearn实现

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# - 构建分类器

# %%
clf = DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# - 训练

# %%
clf.fit(iris_x_train, iris_y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# - 预测

# %%
res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]

# %% [markdown]
# - 评估

# %%
accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))
# Out:
# 预测正确率：93%

# %% [markdown]
# - 可视化

# %%
draw(clf)
# Out:
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 4. 逻辑回归算法
#
# [1]. 基本思想
#
# 一种解释：
#
# 训练：通过一种映射方式，将特征X = (x1, x2) 映射成P(y = ck), 求使得所有概率之积最大化的映射方式里的参数
#
# 预测：计算p(y = ck)取概率最大的哪个类别作为预测对象的分类
#
# [2]. sklearn实现

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# - 构建分类器对象

# %%
clf = LogisticRegression(solver = 'saga', max_iter = 1000)
clf
# Out:
# LogisticRegression(max_iter=1000, solver='saga')

# %% [markdown]
# - 训练， 预测，评估，可视化

# %%
clf.fit(iris_x_train, iris_y_train)

res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)

accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))

draw(clf)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]
# 预测正确率：93%
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 支持向量机算法
#
# [1]. 基本思想
#
# 以二分类为例，假设数据可用一个超平面完全分开：
#
# 用一个超平面将两类数据完全分开，且最近点到平面的距离最大
# ![svc](./pcs/svc.png "svc")
#
# [2]. sklearn实现

# %%
from sklearn.svm import SVC

# %% [markdown]
# - 构建分类器

# %%
clf = SVC()
clf
# Out:
# SVC()

# %% [markdown]
# - 训练，预测，评估，可视化

# %%
clf.fit(iris_x_train, iris_y_train)

res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)

accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))

draw(clf)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]
# 预测正确率：93%
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 集成算法——随机森林
#
# [1]. 训练集m, 有放回的随机抽取m个数据，构成一组，共抽取n组采样集，n组采样集训练得到n个弱分类器，弱分类器一般用决策树或神经网络将n个弱分类器组合得到强分类器
#
# [2]. sklearn实现

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# - 构建分类器对象

# %%
clf = RandomForestClassifier()
clf
# Out:
# RandomForestClassifier()

# %% [markdown]
# - 训练，预测，评估，可视化

# %%
clf.fit(iris_x_train, iris_y_train)

res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)

accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))

draw(clf)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]
# 预测正确率：93%
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 7. 集成方法——Adaboost
#
# [1]. 基本思想
#
# 训练集m, 用初始数据权重训练得到第一个弱分类器，根据误差率计算弱分类器系数，更新数据的权重
#
# 使用新的权重训练得到第二个弱分类器，以此类推
#
# 根据各自的系数，将所有弱分类器加权求和获得强分类器
#
# [2]. sklearn实现

# %%
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# - 构建分类器对象

# %%
clf = AdaBoostClassifier()
clf
# Out:
# AdaBoostClassifier()

# %% [markdown]
# - 训练，预测，评估，可视化

# %%
clf.fit(iris_x_train, iris_y_train)

res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)

accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))

draw(clf)
# Out:
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]
# 预测正确率：93%

# %% [markdown]
# ## 8. 集成方法——梯度提升树GBDT
#
# [1]. 基本思想
#
# 训练集m, 获得第一个弱分类器，获得残差，然后不断地拟合残差
#
# 所有弱分类器相加得到强分类器
#
# [2]. sklearn实现

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# - 构建分类器对象

# %%
clf = GradientBoostingClassifier()
clf
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# - 训练，预测，评估，可视化

# %%
clf.fit(iris_x_train, iris_y_train)

res = clf.predict(iris_x_test)
print(res)
print(iris_y_test.values)

accuracy = clf.score(iris_x_test, iris_y_test)
print("预测正确率：{:.0%}".format(accuracy))

draw(clf)
# Out:
# [1 2 2 2 2 0 0 2 2 0 0 2 1 1 0 2 2 2 2 0 1 2 0 1 2 0 1 1 2 0]
# [1 2 2 2 2 0 0 2 2 0 0 1 1 1 0 2 2 1 2 0 1 2 0 1 2 0 1 1 2 0]
# 预测正确率：93%
# D:\WorkSoftware\Install\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 大杀器
#
# [1]. xgboost
#
# GBDT的损失函数只对误差部分做负梯度（一阶泰勒）展开
#
# XGBoost损失函数对误差部分做二阶泰勒展开，更加准确，更快收敛
#
# [2]. lightgbm
#
# 微软：快速的，分布式的，高性能的基于决策树算法的梯度提升框架
#
# 速度更快
#
# [3]. stacking
#
# 堆叠或者叫模型融合
#
# 先建立几个简单的模型进行训练，第二级学习器会基于前级模型的预测结果进行再训练
#
# [4]. 神经网络
